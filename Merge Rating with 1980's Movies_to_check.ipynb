# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# #read CSV

# %%
df_1980_movie=pd.read_csv("/content/drive/MyDrive/2209-Data/Projets/Projet2/MMA/00_CSV_files/2022_10_19_database_BASICS_1980.csv",sep=';')

# %%
df_1980_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27595 entries, 0 to 27594
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          27595 non-null  object
#  1   titleType       27595 non-null  object
#  2   primaryTitle    27595 non-null  object
#  3   originalTitle   27595 non-null  object
#  4   isAdult         27595 non-null  bool
#  5   startYear       27595 non-null  int64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  21873 non-null  float64
#  8   genres          27595 non-null  object
# dtypes: bool(1), float64(2), int64(1), object(5)
# memory usage: 1.7+ MB

# %%
df_Rating=pd.read_csv("https://datasets.imdbws.com/title.principals.tsv.gz",sep='\t')

# %%
df_Rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1238835 entries, 0 to 1238834
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1238835 non-null  object
#  1   averageRating  1238835 non-null  float64
#  2   numVotes       1238835 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 28.4+ MB

# %% [markdown]
# #Keep 'Tconst' in Ratings that also in the 1980's Movies CSV

# %%
df_Rating=df_Rating[df_Rating['tconst'].isin(df_1980_movie['tconst'])]

# %% [markdown]
# #Merge the 2 Dataframe.
# To add the averagerating & nomVote in the 1980's Movies CSV

# %%
df_movie_1980_rating=df_1980_movie.merge(df_Rating, on='tconst',how='left')

# %%
df_movie_1980_rating
# Out:
#           tconst titleType                 primaryTitle  \
# 0      tt0036606     movie  Another Time, Another Place
# 1      tt0038687     movie           Let There Be Light
# 2      tt0057461     movie       La rosa de los vientos
# 3      tt0062181     movie                 Rece do góry
# 4      tt0064820     movie       The Plot Against Harry
# ...          ...       ...                          ...
# 27590  tt9866884     movie         Samsaram O Sangeetam
# 27591  tt9898368     movie    Langit Tidak Selalu Cerah
# 27592  tt9899972     movie            Spring Comes Late
# 27593  tt9900354     movie  Anak Sulung Tujuh Keturunan
# 27594  tt9911750     movie                Chambu Gabale
#
#                      originalTitle  isAdult  startYear  endYear  \
# 0      Another Time, Another Place    False       1983      NaN
# 1               Let There Be Light    False       1980      NaN
# 2           La rosa de los vientos    False       1983      NaN
# ...

# %% [markdown]
# #export CSV

# %%
df_movie_1980_rating.to_csv('/content/drive/MyDrive/2209-Data/Projets/Projet2/MMA/00_CSV_files/2022_10_20_database_1980_Rating.csv',sep=';')
