# %% [markdown]
# <a href="https://colab.research.google.com/github/AudreyMuller/Recommandation_Films_1980_s/blob/Maria/les_10_meilleurs_r%C3%A9alisateurs_des_ann%C3%A9es_1980%E2%80%99s_merge_Rating_and_CREW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Read CSV

# %%
df_Rating=pd.read_csv('//content/drive/MyDrive/2209-Data/Projets/Projet2/MMA/00_CSV_files/2022_10_20_database_1980_Rating.csv', sep=';')

# %%
df_Rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27595 entries, 0 to 27594
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      27595 non-null  int64
#  1   tconst          27595 non-null  object
#  2   titleType       27595 non-null  object
#  3   primaryTitle    27595 non-null  object
#  4   originalTitle   27595 non-null  object
#  5   isAdult         27595 non-null  bool
#  6   startYear       27595 non-null  int64
#  7   endYear         0 non-null      float64
#  8   runtimeMinutes  21873 non-null  float64
#  9   genres          27595 non-null  object
#  10  averageRating   19689 non-null  float64
#  11  numVotes        19689 non-null  float64
# dtypes: bool(1), float64(4), int64(2), object(5)
# memory usage: 2.3+ MB

# %%
df_crew_basics=pd.read_csv('//content/drive/MyDrive/2209-Data/Projets/Projet2/MMA/00_CSV_files/2022_10_21_database_1980_CREW.csv', sep=';')

# %%
df_crew_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27595 entries, 0 to 27594
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        27595 non-null  int64
#  1   tconst            27595 non-null  object
#  2   titleType_x       27595 non-null  object
#  3   primaryTitle_x    27595 non-null  object
#  4   originalTitle_x   27595 non-null  object
#  5   startYear_x       27595 non-null  int64
#  6   runtimeMinutes_x  21873 non-null  float64
#  7   genres_x          27595 non-null  object
#  8   directors         23202 non-null  object
#  9   writers           23202 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 2.1+ MB

# %% [markdown]
# ## Merge the tables crew and Basics 1980s

# %%
df_crew_rating=df_Rating.merge(df_crew_basics, on='tconst',how='left')

# %%
df_crew_rating
# Out:
#        Unnamed: 0_x     tconst titleType                 primaryTitle  \
# 0                 0  tt0036606     movie  Another Time, Another Place
# 1                 1  tt0038687     movie           Let There Be Light
# 2                 2  tt0057461     movie       La rosa de los vientos
# 3                 3  tt0062181     movie                 Rece do góry
# 4                 4  tt0064820     movie       The Plot Against Harry
# ...             ...        ...       ...                          ...
# 27590         27590  tt9866884     movie         Samsaram O Sangeetam
# 27591         27591  tt9898368     movie    Langit Tidak Selalu Cerah
# 27592         27592  tt9899972     movie            Spring Comes Late
# 27593         27593  tt9900354     movie  Anak Sulung Tujuh Keturunan
# 27594         27594  tt9911750     movie                Chambu Gabale
#
#                      originalTitle  isAdult  startYear  endYear  \
# ...

# %% [markdown]
# ## I will delete the duplicate columns

# %%
del df_crew_rating['isAdult']

# %%
del df_crew_rating['endYear']

# %%
del df_crew_rating['Unnamed: 0_y']

# %%
del df_crew_rating['titleType_x']

# %%
del df_crew_rating['primaryTitle_x']

# %%
del df_crew_rating['originalTitle_x']

# %%
del df_crew_rating['startYear_x']

# %%
del df_crew_rating['runtimeMinutes_x']

# %%
del df_crew_rating['genres_x']

# %% [markdown]
# ## show final table: CREW and RATING

# %%
df_crew_rating
# Out:
#        Unnamed: 0_x     tconst titleType                 primaryTitle  \
# 0                 0  tt0036606     movie  Another Time, Another Place
# 1                 1  tt0038687     movie           Let There Be Light
# 2                 2  tt0057461     movie       La rosa de los vientos
# 3                 3  tt0062181     movie                 Rece do góry
# 4                 4  tt0064820     movie       The Plot Against Harry
# ...             ...        ...       ...                          ...
# 27590         27590  tt9866884     movie         Samsaram O Sangeetam
# 27591         27591  tt9898368     movie    Langit Tidak Selalu Cerah
# 27592         27592  tt9899972     movie            Spring Comes Late
# 27593         27593  tt9900354     movie  Anak Sulung Tujuh Keturunan
# 27594         27594  tt9911750     movie                Chambu Gabale
#
#                      originalTitle  startYear  runtimeMinutes  \
# 0      Another Time, Another Place       1983           118.0
# ...

# %% [markdown]
# ## 10 best realisateurs des annees 1980's
# ## averageRating>=7

# %%
#df_crew_rating.nlargest(10, 'directors')   # nlargest works only for numerical values

# %% [markdown]
# this is for the top movies actually, not for the directors, I need to link it with an other databse that shows ranoking per director in the 80s

# %%
df_crew_rating[df_crew_rating.averageRating >= 7].sort_values('directors').head(10)
# Out:
#       Unnamed: 0_x     tconst titleType         primaryTitle  \
# 2180          2180  tt0083922     movie  Fanny and Alexander
# 3957          3957  tt0087188     movie    The Ship Sails On
# 6071          6071  tt0091113     movie        Ginger & Fred
# 7282          7282  tt0093267     movie           Intervista
# 7163          7163  tt0093058     movie    Full Metal Jacket
# 895            895  tt0081505     movie          The Shining
# 5437          5437  tt0089881     movie                  Ran
# 624            624  tt0080979     movie            Kagemusha
# 7179          7179  tt0093093     movie  The Glass Menagerie
# 1323          1323  tt0082370     movie  The Woman Next Door
#
#             originalTitle  startYear  runtimeMinutes  \
# 2180  Fanny och Alexander       1982           188.0
# 3957         E la nave va       1983           132.0
# 6071        Ginger e Fred       1986           127.0
# 7282           Intervista       1987           107.0
# ...

# %%
df_crew_rating.groupby('directors').sum()
# Out:
#                      Unnamed: 0_x  startYear  runtimeMinutes  averageRating  \
# directors
# nm0000005                    2180       1982           188.0            8.1
# nm0000019                   17687       7936           505.0           28.6
# nm0000032,nm0381699          2423       1982           101.0            5.8
# nm0000040                    8058       3967           262.0           16.7
# nm0000041                    6061       3965           342.0           16.1
# ...                           ...        ...             ...            ...
# nm9924854,nm1281808         27222       1983            94.0            0.0
# nm9928481                   27227       1981             0.0            0.0
# nm9971967                   27250       1988           137.0            0.0
# nm9983175                   27271       1985           125.0            5.7
# nm9987250                   27280       1984            92.0            0.0
#
#                       numVotes
# directors
# ...

# %%
df_crew_rating.groupby('directors')[['averageRating']].max().head(10)
# Out:
#                      averageRating
# directors
# nm0000005                      8.1
# nm0000019                      7.5
# nm0000032,nm0381699            5.8
# nm0000040                      8.4
# nm0000041                      8.2
# nm0000056                      7.1
# nm0000076                      7.4
# nm0000088                      5.8
# nm0000091                      5.3
# nm0000092,nm0187769            7.5

# %%
df_crew_rating.groupby('directors')[['averageRating']].mean().sort_values(['averageRating'], ascending=False).head(10)
# Out:
#                      averageRating
# directors
# nm3003052                      9.6
# nm2063608                      9.4
# nm0787977                      9.3
# nm6686884                      9.2
# nm0017787,nm0094541            9.2
# nm0838694                      9.1
# nm1173074                      9.0
# nm1067882                      9.0
# nm0787463                      9.0
# nm0355991                      8.9
