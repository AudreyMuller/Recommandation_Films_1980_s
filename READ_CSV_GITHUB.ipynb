# %% [markdown]
# <a href="https://colab.research.google.com/github/AudreyMuller/Recommandation_Films_1980_s/blob/Audrey/READ_CSV_GITHUB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/AudreyMuller/Recommandation_Films_1980_s/Rewiew/00_CSV/database_BASICS_1980.csv", encoding='unicode_escape',sep=';')

# %%
df
# Out:
#           tconst titleType                 primaryTitle  \
# 0      tt0036606     movie  Another Time, Another Place
# 1      tt0038687     movie           Let There Be Light
# 2      tt0057461     movie       La rosa de los vientos
# 3      tt0062181     movie                Rece do gÃ³ry
# 4      tt0064820     movie       The Plot Against Harry
# ...          ...       ...                          ...
# 27590  tt9866884     movie         Samsaram O Sangeetam
# 27591  tt9898368     movie    Langit Tidak Selalu Cerah
# 27592  tt9899972     movie            Spring Comes Late
# 27593  tt9900354     movie  Anak Sulung Tujuh Keturunan
# 27594  tt9911750     movie                Chambu Gabale
#
#                      originalTitle  isAdult  startYear  endYear  \
# 0      Another Time, Another Place    False       1983      NaN
# 1               Let There Be Light    False       1980      NaN
# 2           La rosa de los vientos    False       1983      NaN
# ...
